# %% [markdown]
# <a href="https://colab.research.google.com/github/alibagheribardi/Signal-and-Systems/blob/main/Marks_signal_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

list_names = [
    'ابراهيمي', 'اقاجاني', 'اقاجري', 'الهامي', 'اميني', 'برازجاني',
    'تن زاد', 'تنگ ريز', 'حياتي', 'خميسي', 'دستک', 'روستا', 'زيرراهي',
    'شريفات', 'شهبازي'
]


students_list = {'نام': list_names,
                 'تشویقی': [None] * len(list_names) ,
                 'Exam I': [None] * len(list_names),
                 'Exam II': [None] * len(list_names),
                 'Exam III': [None] * len(list_names),
                 'Final Exam': [None] * len(list_names),
                 }

df = pd.DataFrame(students_list)

df
# Out:
#          نام تشویقی Exam I Exam II Exam III Final Exam
# 0   ابراهيمي   None   None    None     None       None
# 1    اقاجاني   None   None    None     None       None
# 2     اقاجري   None   None    None     None       None
# 3     الهامي   None   None    None     None       None
# 4      اميني   None   None    None     None       None
# 5   برازجاني   None   None    None     None       None
# 6     تن زاد   None   None    None     None       None
# 7    تنگ ريز   None   None    None     None       None
# 8      حياتي   None   None    None     None       None
# 9      خميسي   None   None    None     None       None
# 10      دستک   None   None    None     None       None
# 11     روستا   None   None    None     None       None
# 12   زيرراهي   None   None    None     None       None
# 13    شريفات   None   None    None     None       None
# 14    شهبازي   None   None    None     None       None

# %%
print(students_list)
# Out:
# {'Name': ['ابراهيمي', 'اقاجاني', 'اقاجري', 'الهامي', 'اميني', 'برازجانيتن زاد', 'تنگ ريز', 'حياتي', 'خميسي', 'دستک', 'روستا', 'زيرراهيشريفات', 'شهبازي']}
